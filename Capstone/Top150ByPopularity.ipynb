# %% [markdown]
# FindTop150.py
#
# (C) 2018 by Jay Kaiser <jayckaiser.github.io>
# Created Jan 8, 2018
# Updated Jan 8, 2018
#
# Given the Stat files from the previous step, find the top 150 most "influential" subreddits.
# Output this information into a file that readily shows the ordering and the means for their ratings.
#
# An "influential subreddit" has a large number of comments, unique users, and average message length.
# Posts should also be ranked highly by other users in the subreddit. This indicates active involvement.

# %%
import pickle
import os
import pandas as pd

# %%
def stats2dataframe(directory, file):
    subreddits = pickle.load(open(os.path.join(directory, file), 'rb'))
    
    simpler_figures = []
    
    total_comments = 0
    for subreddit in subreddits:
        subreddit_content = subreddits.get(subreddit)
        
        num_unique_users            = len(subreddit_content.get('unique_users'))
        total_number_of_comments    = subreddit_content.get('total_number_of_comments')
        average_comments_per_person = total_number_of_comments / num_unique_users
        average_score               = subreddit_content.get('total_score') / total_number_of_comments
        average_comment_length      = subreddit_content.get('total_comments_length') / total_number_of_comments
        
        total_comments += total_number_of_comments
        
        simpler_figures.append([subreddit,
                                total_number_of_comments,
                                num_unique_users,
                                average_comments_per_person,
                                average_comment_length,
                                average_score])
           
    subreddits = pd.DataFrame(simpler_figures,
                              columns=['subreddit',
                                       'num_comments',
                                       'num_unique_users',
                                       'avg_comments_per_user',
                                       'avg_comment_length',
                                       'avg_score'])
    
    print("\rIn {}, there were {:,} new comments on Reddit.".format(file, total_comments), end='')
    return subreddits

# %%
rc2013_01 = stats2dataframe('/home/jayckaiser/Dropbox/DataIncubator/Capstone/', 'RC_2013-01.pkl')
# Out:
# In RC_2013-01.pkl, there were 27,919,427 new comments on Reddit.

# %%
rc2013_01.shape
# Out:
# (23916, 6)

# %%
rc2013_01.head()
# Out:
#        subreddit  num_comments  num_unique_users  avg_comments_per_user  \
# 0        Android         89060             16758               5.314477
# 1  todayilearned        353108            106060               3.329323
# 2       politics        470008             62932               7.468506
# 3          funny       1302731            295464               4.409102
# 4  gonewildcurvy         28160              3726               7.557703
#
#    avg_comment_length  avg_score
# 0          197.189412   3.816292
# 1          169.299070   7.080225
# 2          282.881194   4.176435
# 3           99.726815   8.416836
# 4           50.271200   1.348580

# %% [markdown]
# I predict that the number of comments are a strong predictor of the value of a subreddit. Let's investigate whether the other values are valuable as well.

# %%
rc2013_01.sort_values(['num_comments'], ascending=False).head()
# Out:
#     subreddit  num_comments  num_unique_users  avg_comments_per_user  \
# 6   AskReddit       3998326            475861               8.402298
# 3       funny       1302731            295464               4.409102
# 17       pics        922374            257166               3.586687
# 53        WTF        703455            186658               3.768684
# 44     gaming        654238            167831               3.898195
#
#     avg_comment_length  avg_score
# 6           151.145225  10.030516
# 3            99.726815   8.416836
# 17          110.634732   8.155350
# 53          107.895024   7.947862
# 44          131.242108   6.381407

# %% [markdown]
# In January 2013, there were 23,916 subreddits, and the ones in the cell below are the most commented-on ones. I'm betting most of the other subreddits are unused, however. Let's see this in person.

# %%
rc2013_01.sort_values(['avg_comment_length'], ascending=False).head(10)
# Out:
#                  subreddit  num_comments  num_unique_users  \
# 23519           MyEyesBurn             3                 2
# 15589          PN_Official             3                 1
# 23114   everythingimagined             1                 1
# 22033         GlobalIssues             2                 2
# 18024        AvenueBrawler             1                 1
# 5700   1000thworldproblems           214                19
# 23431           Al_Stewart             1                 1
# 21775           testincode             1                 1
# 19786             Kazantip             1                 1
# 21559            warpoetry             2                 1
#
#        avg_comments_per_user  avg_comment_length  avg_score
# 23519               1.500000        26715.666667   1.000000
# 15589               3.000000        16051.333333   1.000000
# 23114               1.000000        15340.000000   1.000000
# 22033               1.000000        11306.500000   1.000000
# 18024               1.000000         9192.000000   1.000000
# 5700               11.263158         8777.794393   2.172897
# 23431               1.000000         7668.000000   2.000000
# 21775               1.000000         6957.000000   1.000000
# 19786               1.000000         6877.000000   1.000000
# 21559               2.000000         6416.000000   1.000000

# %% [markdown]
# It turns out that subreddits with the longest comments on average are all single-pop subreddits or just full of "shitposts" (like in the case of r/1000thworldproblems). In fact, let's filter subreddits by number of total users who've posted and see what changes.

# %%
rc2013_01_greaterThan10 = rc2013_01[ rc2013_01['num_unique_users'] > 10 ]
rc2013_01_greaterThan10.shape
# Out:
# (8868, 6)

# %% [markdown]
# By filtering by subreddits with more than 10 unique posters, I've whittled the total list down to a third. Let's scale this up one more magnitude.

# %%
rc2013_01_greaterThan100 = rc2013_01[ rc2013_01['num_unique_users'] > 100 ]
rc2013_01_greaterThan100.shape
# Out:
# (3186, 6)

# %% [markdown]
# With more than 100 posters, we're left to one eighth the original amount.

# %%
rc2013_01_greaterThan1000 = rc2013_01[ rc2013_01['num_unique_users'] > 1000 ]
rc2013_01_greaterThan1000.shape
# Out:
# (686, 6)

# %% [markdown]
# With more than 1000, we're down to only one 40th the original amount. We're getting close.

# %%
rc2013_01_greaterThan1000.sort_values(['avg_comment_length']).head(15)
# Out:
#                  subreddit  num_comments  num_unique_users  \
# 235                   milf          3460              1511
# 759           GoneWildPlus         19375              1981
# 4            gonewildcurvy         28160              3726
# 391           ladybonersgw         22239              3084
# 2470                   ass          2811              1440
# 240               gonewild        212226             28211
# 300                Boobies          2642              1427
# 1708                 curvy          2181              1078
# 1476             RealGirls          9001              4366
# 510          treesgonewild          2770              1069
# 814       girlsinyogapants          1942              1154
# 1852             nsfw_gifs          3244              1758
# 2198        notinteresting          5574              1604
# 2491  PrettyGirlsUglyFaces          2289              1133
# 927                 Celebs          4320              1633
#
#       avg_comments_per_user  avg_comment_length  avg_score
# 235                2.289874           46.697399   2.198266
# 759                9.780414           49.353961   1.457703
# 4                  7.557703           50.271200   1.348580
# 391                7.211089           51.392464   2.133954
# 2470               1.952083           51.481323   2.253646
# 240                7.522810           51.646353   1.576060
# 300                1.851437           52.641181   2.700606
# 1708               2.023191           53.876662   2.259972
# 1476               2.061612           54.248972   3.193978
# 510                2.591207           55.496390   1.983394
# 814                1.682842           57.415036   3.897528
# 1852               1.845279           57.451603   3.539766
# 2198               3.475062           60.716182   3.506279
# 2491               2.020300           61.833989   3.461774
# 927                2.645438           62.845370   3.631019

# %% [markdown]
# It turns out that the most popular subreddits with the least to contribute (as determined by avg comment length) are all porn subreddits.
#
# Let's dare to try 10,000.

# %%
rc2013_01_greaterThan10000 = rc2013_01[ rc2013_01['num_unique_users'] > 10000 ]
rc2013_01_greaterThan10000.shape
# Out:
# (55, 6)

# %%
rc2013_01_greaterThan10000.sort_values('avg_comment_length', ascending=False)
# Out:
#                 subreddit  num_comments  num_unique_users  \
# 24             askscience         39947             11671
# 190       TwoXChromosomes         60077             11161
# 98      explainlikeimfive         56709             17439
# 523                bestof         25909             10466
# 2                politics        470008             62932
# 156                   sex         90738             19427
# 25               buildapc        104973             12139
# 70                  Games        170897             29116
# 311               science         69621             26626
# 467                Frugal         58569             17249
# 226               atheism        281837             60723
# 114             worldnews        252793             57961
# 21             technology        184465             52022
# 112                  news         58836             15022
# 397               Fitness         75500             15573
# 282                   wow         54077             10817
# 0                 Android         89060             16758
# 180                  guns        156742             15345
# 205                 DotA2        154945             15458
# 31                   IAmA        350507            120297
# 491           JusticePorn         51777             16047
# 1           todayilearned        353108            106060
# 91              starcraft        118463             15307
# 37      malefashionadvice        119851             15848
# 413           LifeProTips         48701             20470
# 38        leagueoflegends        484696             60586
# 7           AdviceAnimals        557399            144860
# 101                movies        195035             59791
# 6               AskReddit       3998326            475861
# 54                 soccer        143947             13708
# 268                skyrim         62717             12692
# 74                  Music         94075             44936
# 15                 videos        341257            109884
# 44                 gaming        654238            167831
# 36                    CFB        175517             11884
# 261                hockey        114702             11535
# 123                   nba        196791             14118
# 32                    nfl        423906             28597
# 93              Minecraft        124054             26081
# 47                 cringe         95159             22474
# 17                   pics        922374            257166
# 53                    WTF        703455            186658
# 11                  trees        315848             60001
# 134               pokemon        151595             24439
# 661              woahdude         18728             10124
# 689          reactiongifs         30226             12940
# 3                   funny       1302731            295464
# 75                    aww        184882             80851
# 10                   gifs         89655             37728
# 94    fffffffuuuuuuuuuuuu         81582             23823
# 471     mildlyinteresting         49074             22093
# 67             cringepics         85168             16096
# 278  ImGoingToHellForThis         38816             14516
# 89                  4chan         38563             13724
# 240              gonewild        212226             28211
#
#      avg_comments_per_user  avg_comment_length  avg_score
# 24                3.422757          413.287731   5.978446
# 190               5.382761          363.329294   7.666944
# 98                3.251849          358.851734   6.192509
# 523               2.475540          288.473388   5.465128
# 2                 7.468506          282.881194   4.176435
# 156               4.670716          268.064019   6.074412
# 25                8.647582          267.403751   2.036438
# 70                5.869522          261.974365   6.827294
# 311               2.614775          253.182703   5.013128
# 467               3.395501          251.644505   6.176937
# 226               4.641355          245.170581   4.257617
# 114               4.361433          233.457540   6.065552
# 21                3.545904          229.703288   6.629279
# 112               3.916656          223.498317   4.804117
# 397               4.848135          220.826318   5.368623
# 282               4.999260          201.791039   2.948777
# 0                 5.314477          197.189412   3.816292
# 180              10.214532          194.302969   4.215622
# 205              10.023612          192.626739   4.290832
# 31                2.913680          177.438528  11.067933
# 491               3.226584          171.342333  10.129826
# 1                 3.329323          169.299070   7.080225
# 91                7.739139          163.133392   5.110845
# 37                7.562532          162.965933   4.381682
# 413               2.379140          159.388575   7.103756
# 38                8.000132          155.667670   5.390558
# 7                 3.847846          154.645721   6.780685
# 101               3.261946          151.343805   7.199728
# 6                 8.402298          151.145225  10.030516
# 54               10.500948          149.877267   6.932816
# 268               4.941459          146.703605   5.684137
# 74                2.093533          144.119596   5.212862
# 15                3.105611          136.563103   9.807901
# 44                3.898195          131.242108   6.381407
# 36               14.769185          126.188005   5.536068
# 261               9.943823          125.414997   5.261975
# 123              13.939014          120.441595   5.347313
# 32               14.823443          117.091702   6.858525
# 93                4.756489          113.747908   5.104124
# 47                4.234182          110.948013   9.756219
# 17                3.586687          110.634732   8.155350
# 53                3.768684          107.895024   7.947862
# 11                5.264046          107.646938   4.538490
# 134               6.202995          103.829493   5.808674
# 661               1.849862          103.588798   6.128204
# 689               2.335858          103.424767   6.443856
# 3                 4.409102           99.726815   8.416836
# 75                2.286700           97.600799   5.843186
# 10                2.376352           97.421583   8.161653
# 94                3.424506           95.349048   5.185237
# 471               2.221247           94.514896   8.564474
# 67                5.291252           88.427156  12.488305
# 278               2.674015           87.840040   5.832208
# 89                2.809895           85.158779  13.780074
# 240               7.522810           51.646353   1.576060

# %% [markdown]
# At 10,000 unique users who've posted apiece, there are still 55 subreddits remaining. This is promising, especially because I only need ~150 subreddits in total to study.
#
# Before moving forward, for fun I want to see what the most circle-jerking subreddit is.

# %%
rc2013_01.sort_values(['avg_score'], ascending=False).head(20)
# Out:
#                    subreddit  num_comments  num_unique_users  \
# 12133           thatHappened             3                 3
# 9003                gonewidl            18                14
# 22024       mildlyterrifying             1                 1
# 20580           LatvianJokes            47                24
# 23603       WhyIsntSRSBanned             2                 2
# 21444             frugaljerk             1                 1
# 370         photoshopbattles         17432              5819
# 259               TheJerkies           930               355
# 16321                 iFunny             1                 1
# 19502             depressing             1                 1
# 7296        Watch_Me_Ban_You             2                 2
# 11213               GoneMild             3                 3
# 1599              ProRevenge           157                80
# 16749     mylittlemensrights             1                 1
# 12328    TeachMeToBeOffended            15                10
# 7170               asseffect             1                 1
# 1000         explainlikeIAmA          6315              3027
# 1660                 castles           212                93
# 5979   2012RedditMovieAwards           823               235
# 22861  im14andthisisGonewild             1                 1
#
#        avg_comments_per_user  avg_comment_length  avg_score
# 12133               1.000000          132.333333  90.333333
# 9003                1.285714           43.555556  77.277778
# 22024               1.000000           26.000000  53.000000
# 20580               1.958333          105.425532  32.617021
# 23603               1.000000           40.000000  30.500000
# 21444               1.000000           69.000000  30.000000
# 370                 2.995704           69.797269  28.203132
# 259                 2.619718          170.437634  27.110753
# 16321               1.000000           70.000000  26.000000
# 19502               1.000000           18.000000  25.000000
# 7296                1.000000           72.500000  23.500000
# 11213               1.000000           65.666667  23.000000
# 1599                1.962500          133.949045  21.331210
# 16749               1.000000          172.000000  21.000000
# 12328               1.500000          174.200000  20.733333
# 7170                1.000000          100.000000  20.000000
# 1000                2.086224          213.496912  19.767221
# 1660                2.279570          246.339623  19.740566
# 5979                3.502128          133.346294  19.269745
# 22861               1.000000           65.000000  18.000000

# %% [markdown]
# And let's see which subreddit has the highest number of posts per person.

# %%
rc2013_01.sort_values(['avg_comments_per_user'], ascending=False).head(20)
# Out:
#                    subreddit  num_comments  num_unique_users  \
# 43                 videoinfo          1172                 1
# 13184                comment          1060                 3
# 638            ModerationLog          9456                39
# 7377      WorldLeadersBattle           138                 1
# 5832       PhantomandFriends           402                 3
# 76      illjustleavethishere           248                 2
# 3059         TheHoneyFuckles           733                 6
# 124    Random_Acts_Of_Amazon        152374              1625
# 16775     FantasyRealignment           967                11
# 980         ConnectedCareers          6146                73
# 19732        LiberalButtHurt           483                 6
# 9261                    2MSF            80                 1
# 775     tamrielscholarsguild          3198                43
# 84        RandomActsOfPolish         48972               755
# 80                 MLPLounge        135795              2260
# 10057          TamrielsArena          1513                27
# 5128         reddit_api_test           165                 3
# 21544                 ottotd          1082                20
# 2604              FryeMadden          3525                67
# 3534       JapanesePornIdols            98                 2
#
#        avg_comments_per_user  avg_comment_length  avg_score
# 43               1172.000000         1115.086177   1.000000
# 13184             353.333333            7.931132   1.003774
# 638               242.461538         1592.360618   1.000529
# 7377              138.000000          162.239130   1.028986
# 5832              134.000000          247.601990   1.965174
# 76                124.000000          125.370968   1.000000
# 3059              122.166667           95.451569   1.008186
# 124                93.768615          139.939799   1.437712
# 16775              87.909091           35.596691   1.020683
# 980                84.191781           99.863488   2.030101
# 19732              80.500000          737.302277   0.987578
# 9261               80.000000          184.087500   1.000000
# 775                74.372093          164.064103   2.837711
# 84                 64.863576          132.848117   1.697399
# 80                 60.086283          126.255039   2.698870
# 10057              56.037037          183.248513   1.516854
# 5128               55.000000           50.103030   1.000000
# 21544              54.100000           73.246765   2.776340
# 2604               52.611940           78.251064   1.247092
# 3534               49.000000           92.724490   1.030612

# %% [markdown]
# Now, how can we determine the most influential, most informative subreddits? Here is what I posit: let's find from the subreddits with over 1,000 unique users the top 500 subreddits, the highest subreddits ranked by number of comments, number of unique users, and average comment length. Then, from these, let's limit them to the top 500 of each category. Then, if we took the union of subreddits across all three, we can whittle the list total list of ~600 down to a minimal number. This final subset will be those subreddits that have the most comments,

# %%
rc2013_01_500NC = rc2013_01_greaterThan1000.sort_values(['num_comments'], ascending=False)[:500]
rc2013_01_500NC.head(10)
# Out:
#           subreddit  num_comments  num_unique_users  avg_comments_per_user  \
# 6         AskReddit       3998326            475861               8.402298
# 3             funny       1302731            295464               4.409102
# 17             pics        922374            257166               3.586687
# 53              WTF        703455            186658               3.768684
# 44           gaming        654238            167831               3.898195
# 7     AdviceAnimals        557399            144860               3.847846
# 38  leagueoflegends        484696             60586               8.000132
# 2          politics        470008             62932               7.468506
# 32              nfl        423906             28597              14.823443
# 1     todayilearned        353108            106060               3.329323
#
#     avg_comment_length  avg_score
# 6           151.145225  10.030516
# 3            99.726815   8.416836
# 17          110.634732   8.155350
# 53          107.895024   7.947862
# 44          131.242108   6.381407
# 7           154.645721   6.780685
# 38          155.667670   5.390558
# 2           282.881194   4.176435
# 32          117.091702   6.858525
# 1           169.299070   7.080225

# %%
rc2013_01_500NUU = rc2013_01_greaterThan1000.sort_values(['num_unique_users'], ascending=False)[:500]
rc2013_01_500NUU.head(10)
# Out:
#         subreddit  num_comments  num_unique_users  avg_comments_per_user  \
# 6       AskReddit       3998326            475861               8.402298
# 3           funny       1302731            295464               4.409102
# 17           pics        922374            257166               3.586687
# 53            WTF        703455            186658               3.768684
# 44         gaming        654238            167831               3.898195
# 7   AdviceAnimals        557399            144860               3.847846
# 31           IAmA        350507            120297               2.913680
# 15         videos        341257            109884               3.105611
# 1   todayilearned        353108            106060               3.329323
# 75            aww        184882             80851               2.286700
#
#     avg_comment_length  avg_score
# 6           151.145225  10.030516
# 3            99.726815   8.416836
# 17          110.634732   8.155350
# 53          107.895024   7.947862
# 44          131.242108   6.381407
# 7           154.645721   6.780685
# 31          177.438528  11.067933
# 15          136.563103   9.807901
# 1           169.299070   7.080225
# 75           97.600799   5.843186

# %%
rc2013_01_500ACL = rc2013_01_greaterThan1000.sort_values(['avg_comment_length'], ascending=False)[:500]
rc2013_01_500ACL.head(10)
# Out:
#              subreddit  num_comments  num_unique_users  avg_comments_per_user  \
# 645            POLITIC         10794              1094               9.866545
# 1215      listentothis          8121              3645               2.227984
# 1285     buildapcforme          6494              1147               5.661726
# 201      AskHistorians         28316              5931               4.774237
# 2168   NeutralPolitics          4238              1035               4.094686
# 565   AskSocialScience          3999              1190               3.360504
# 2095          TrueFilm          6197              1614               3.839529
# 295        TrueAtheism         13913              2987               4.657851
# 396     DebateReligion         42276              2005              21.085287
# 164         philosophy         22410              4251               5.271701
#
#       avg_comment_length  avg_score
# 645          1405.432740   1.040578
# 1215          675.043837   2.819973
# 1285          549.285340   1.361411
# 201           533.590479   6.846836
# 2168          521.894998   4.093204
# 565           511.876219   3.428107
# 2095          485.583024   4.553816
# 295           481.054769   4.105010
# 396           480.546835   2.515186
# 164           450.064614   2.656716

# %%
rc2013_01_mostRelevant = pd.merge(pd.merge(rc2013_01_500ACL, rc2013_01_500NC, how='inner'), rc2013_01_500NUU, how='inner')

# %%
rc2013_01_mostRelevant150 = rc2013_01_mostRelevant.sort_values(['num_unique_users'], ascending=False)[:150]

# %%
rc2013_01_mostRelevant150
# Out:
#                subreddit  num_comments  num_unique_users  \
# 304            AskReddit       3998326            475861
# 295        AdviceAnimals        557399            144860
# 241                 IAmA        350507            120297
# 266        todayilearned        353108            106060
# 60              politics        470008             62932
# 108              atheism        281837             60723
# 290      leagueoflegends        484696             60586
# 303               movies        195035             59791
# 118            worldnews        252793             57961
# 123           technology        184465             52022
# 317                Music         94075             44936
# 82                 Games        170897             29116
# 90               science         69621             26626
# 287          LifeProTips         48701             20470
# 77                   sex         90738             19427
# 28     explainlikeimfive         56709             17439
# 94                Frugal         58569             17249
# 188              Android         89060             16758
# 261          JusticePorn         51777             16047
# 282    malefashionadvice        119851             15848
# 139              Fitness         75500             15573
# 199                DotA2        154945             15458
# 193                 guns        156742             15345
# 280            starcraft        118463             15307
# 135                 news         58836             15022
# 306               soccer        143947             13708
# 313               skyrim         62717             12692
# 79              buildapc        104973             12139
# 7             askscience         39947             11671
# 25       TwoXChromosomes         60077             11161
# ..                   ...           ...               ...
# 283               sports         10226              4091
# 125           masseffect         21904              4064
# 217          Borderlands         19905              3986
# 35             Parenting         16510              3984
# 38               gamedev         16698              3975
# 27               skeptic         14247              3910
# 269                  PS3         14945              3862
# 305     TheLastAirbender         14363              3861
# 16                   rpg         18384              3841
# 276         snowboarding         18487              3814
# 131          Homebrewing         24804              3802
# 23               writing         17170              3770
# 162              toronto         21046              3649
# 0           listentothis          8121              3645
# 247              chicago         14342              3625
# 292                Autos         14020              3595
# 267         pettyrevenge         13634              3573
# 262                  Art          7945              3566
# 185              Seattle         15172              3548
# 237    frugalmalefashion         12566              3498
# 219                  nyc         12736              3366
# 230           television          9916              3362
# 138          FanTheories          8502              3314
# 93                  lgbt         10836              3291
# 11   PoliticalDiscussion         39781              3276
# 42            Futurology         12141              3263
# 272            EarthPorn          6456              3199
# 179              gadgets          7247              3191
# 15             Economics         17801              3183
# 236                vinyl         19030              3180
#
#      avg_comments_per_user  avg_comment_length  avg_score
# 304               8.402298          151.145225  10.030516
# 295               3.847846          154.645721   6.780685
# 241               2.913680          177.438528  11.067933
# 266               3.329323          169.299070   7.080225
# 60                7.468506          282.881194   4.176435
# 108               4.641355          245.170581   4.257617
# 290               8.000132          155.667670   5.390558
# 303               3.261946          151.343805   7.199728
# 118               4.361433          233.457540   6.065552
# 123               3.545904          229.703288   6.629279
# 317               2.093533          144.119596   5.212862
# 82                5.869522          261.974365   6.827294
# 90                2.614775          253.182703   5.013128
# 287               2.379140          159.388575   7.103756
# 77                4.670716          268.064019   6.074412
# 28                3.251849          358.851734   6.192509
# 94                3.395501          251.644505   6.176937
# 188               5.314477          197.189412   3.816292
# 261               3.226584          171.342333  10.129826
# 282               7.562532          162.965933   4.381682
# 139               4.848135          220.826318   5.368623
# 199              10.023612          192.626739   4.290832
# 193              10.214532          194.302969   4.215622
# 280               7.739139          163.133392   5.110845
# 135               3.916656          223.498317   4.804117
# 306              10.500948          149.877267   6.932816
# 313               4.941459          146.703605   5.684137
# 79                8.647582          267.403751   2.036438
# 7                 3.422757          413.287731   5.978446
# 25                5.382761          363.329294   7.666944
# ..                     ...                 ...        ...
# 283               2.499633          161.999315   6.023665
# 125               5.389764          229.166682   5.162664
# 217               4.993728          184.474454   3.592565
# 35                4.144076          335.167535   3.569715
# 38                4.200755          327.513894   2.812313
# 27                3.643734          358.901313   4.842704
# 269               3.869757          168.391837   2.576715
# 305               3.720021          150.064471   5.878159
# 16                4.786254          380.339806   3.315546
# 276               4.847142          166.027371   2.268459
# 131               6.523935          225.891268   2.183277
# 23                4.554377          368.123762   2.912930
# 162               5.767608          209.012639   3.511926
# 0                 2.227984          675.043837   2.819973
# 247               3.956414          175.437387   3.329661
# 292               3.899861          155.281098   3.234665
# 267               3.815841          169.194220   8.827637
# 262               2.227987          170.476149   2.559220
# 185               4.276212          199.330148   3.013050
# 237               3.592338          178.796196   2.331689
# 219               3.783720          183.821844   3.288709
# 230               2.949435          180.360024   4.321702
# 138               2.565480          220.902611   7.056693
# 93                3.292616          251.661037   4.300757
# 11               12.143162          396.681707   2.162163
# 42                3.720809          308.760399   4.116300
# 272               2.018131          167.796314   3.208178
# 179               2.271075          202.109287   3.789982
# 15                5.592523          382.292905   3.185270
# 236               5.984277          179.013505   2.229637
#
# [150 rows x 6 columns]

# %% [markdown]
# Now, let's write some code to automatically extract these top subreddits from a file and save it into a pickled dataframe just like the one above.

# %%
def extractTop150(directory, file):
    raw_dataframe = stats2dataframe(directory, file)
    raw_dataframe = raw_dataframe[ raw_dataframe['num_unique_users'] > 1000 ]
    
    top500NC = raw_dataframe.sort_values(['num_comments'], ascending=False)[:500]
    top500NUU = raw_dataframe.sort_values(['num_unique_users'], ascending=False)[:500]
    top500ACL = raw_dataframe.sort_values(['avg_comment_length'], ascending=False)[:500]
    
    unioned_subset = pd.merge(pd.merge(top500NC, top500NUU, how='inner'), top500ACL, how='inner')
    
    return unioned_subset.sort_values(['num_unique_users'], ascending=False)[:150]


def saveToPickle(directory, file, dataframe):
    dataframe.to_pickle(os.path.join(directory, file))

# %%
stats_directory = "/media/jayckaiser/My Passport/reddit/stats/"
top150_directory = "/media/jayckaiser/My Passport/reddit/top150/"

if True:  # This has already been done once so I don't need to do it again.
    # files_to_do = sorted(os.listdir(stats_directory))
    files_to_do = ['RC_2013-03.pkl']
    for file in files_to_do:
        saveToPickle(top150_directory, file,    extractTop150(stats_directory, file) )
# Out:
# In RC_2006-12.pkl, there were 56,249 new comments on Reddit.
# /home/jayckaiser/anaconda/lib/python3.6/site-packages/pandas/core/reshape/merge.py:1457: RuntimeWarning: divide by zero encountered in long_scalars
#   stride //= shape[i]
# In RC_2017-11.pkl, there were 81,433,342 new comments on Reddit.

# %% [markdown]
# And for the sake of easily extracting the full set for future parsing, here is one final script for this notebook.

# %%
def extractUniqueSubreddits(directory):
    master_set = set()
    
    for file in os.listdir(directory):
        if file == 'ALL.pkl':
            continue
        
        print("\rReading {}.".format(file), end='')
        dataframe = pd.read_pickle(os.path.join(directory, file))
        
        subreddits = set(dataframe['subreddit'])
        master_set = master_set | subreddits
    
    print("\rFinished all files.")
    return master_set


output_path = os.path.join(top150_directory, 'ALL.pkl')

if False:
    master_set = extractUniqueSubreddits(top150_directory)
    pickle.dump(master_set, open(output_path, 'wb'))

# %%
import pprint

pprint.pprint(pickle.load(open(output_path, 'rb')))
# Out:
# {'13ReasonsWhy',
#  '3DS',
#  '3Dprinting',
#  '4chan',
#  'ADHD',
#  'AMA',
#  'AbandonedPorn',
#  'Advice',
#  'AdviceAnimals',
#  'Anarchism',
#  'Android',
#  'Animesuggest',
#  'Aquariums',
#  'Art',
#  'AsianBeauty',
#  'AskAnAmerican',
#  'AskHistorians',
#  'AskMen',
#  'AskReddit',
#  'AskScienceFiction',
#  'AskThe_Donald',
#  'AskTrumpSupporters',
#  'AskWomen',
#  'Atlanta',
#  'Austin',
#  'Autos',
#  'BabyBumps',
#  'Bad_Cop_No_Donut',
#  'Banished',
#  'Battleborn',
#  'Battlefield',
#  'Bestof2011',
#  'Bioshock',
#  'Bitcoin',
#  'Borderlands',
#  'Borderlands2',
#  'BuyItForLife',
#  'CFB',
#  'CODGhosts',
#  'Calgary',
#  'CanadaPolitics',
#  'CasualConversation',
#  'Christianity',
#  'ClickerHeroes',
#  'Coffee',
#  'ColbertRally',
#  'CompetitiveForHonor',
#  'CompetitiveHS',
#  'Competitiveoverwatch',
#  'Conservative',
#  'Cooking',
#  'CruciblePlaybook',
#  'CrusaderKings',
#  'Cynicalbrit',
#  'DAE',
#  'DIY',
#  'DNCleaks',
#  'DarkNetMarkets',
#  'DarkSouls2',
#  'DeadBedrooms',
#  'Denmark',
#  'Denver',
#  'Design',
#  'Dexter',
#  'Diablo',
#  'Diablo3Strategy',
#  'DivinityOriginalSin',
#  'DnD',
#  'Documentaries',
#  'DoesAnybodyElse',
#  'Dogfort',
#  'DornerCase',
#  'DotA2',
#  'Drugs',
#  'EDH',
#  'EarthPorn',
#  'Economics',
#  'EliteDangerous',
#  'EnoughTrumpSpam',
#  'Entrepreneur',
#  'Eve',
#  'EvolveGame',
#  'FFRecordKeeper',
#  'FFXV',
#  'FORTnITE',
#  'Fallout',
#  'FanTheories',
#  'Fantasy',
#  'FantasyLCS',
#  'Favors',
#  'FearTheWalkingDead',
#  'Filmmakers',
#  'FinalFantasy',
#  'Fitness',
#  'FoodPorn',
#  'Frugal',
#  'Futurology',
#  'GameDeals',
#  'GamerGhazi',
#  'Games',
#  'Gaming4Gamers',
#  'GetMotivated',
#  'GlobalOffensive',
#  'Guildwars2',
#  'Guitar',
#  'Gunners',
#  'HIMYM',
#  'Health',
#  'HeroesofNewerth',
#  'HistoryPorn',
#  'Homebrewing',
#  'HouseOfCards',
#  'IASIP',
#  'IAmA',
#  'IWantToLearn',
#  'ImGoingToHellForThis',
#  'Inglip',
#  'InternetIsBeautiful',
#  'JUSTNOMIL',
#  'Jokes',
#  'JonTron',
#  'JusticePorn',
#  'Justrolledintotheshop',
#  'KerbalSpaceProgram',
#  'KotakuInAction',
#  'LadyBoners',
#  'LateStageCapitalism',
#  'Libertarian',
#  'LifeProTips',
#  'LosAngeles',
#  'LucidDreaming',
#  'MH370',
#  'MMA',
#  'MMORPG',
#  'MakeupAddiction',
#  'MakingaMurderer',
#  'MapPorn',
#  'MarchAgainstTrump',
#  'Marijuana',
#  'MarioMaker',
#  'MensRights',
#  'Metal',
#  'Military',
#  'Minecraft',
#  'ModernMagic',
#  'MonsterHunter',
#  'MorbidReality',
#  'Music',
#  'NSFW_GIF',
#  'Naruto',
#  'NetflixBestOf',
#  'Neverwinter',
#  'NoFap',
#  'NoStupidQuestions',
#  'OkCupid',
#  'OnePiece',
#  'OperationGrabAss',
#  'OutOfTheLoop',
#  'Overwatch',
#  'OverwatchUniversity',
#  'PS3',
#  'PS4',
#  'Parenting',
#  'Pathfinder_RPG',
#  'Physics',
#  'Planetside',
#  'Playdate',
#  'PoliticalDiscussion',
#  'Political_Revolution',
#  'Portal',
#  'Portland',
#  'ProtectAndServe',
#  'PuzzleAndDragons',
#  'Python',
#  'QuotesPorn',
#  'Random_Acts_Of_Pizza',
#  'ReviewThis',
#  'Rift',
#  'RimWorld',
#  'SOPA',
#  'SSBM',
#  'SSBPM',
#  'SandersForPresident',
#  'Scotland',
#  'Seattle',
#  'SeattleWA',
#  'Shadowverse',
#  'ShitRedditSays',
#  'ShouldIbuythisgame',
#  'SilkRoad',
#  'SimCity',
#  'SkincareAddiction',
#  'Smite',
#  'SomebodyMakeThis',
#  'SquaredCircle',
#  'StarWars',
#  'Steam',
#  'SteamGameSwap',
#  'SteamTrade',
#  'Stellaris',
#  'SubredditDrama',
#  'SuicideWatch',
#  'Surface',
#  'TalesFromRetail',
#  'Terraria',
#  'TheLastAirbender',
#  'TheRedPill',
#  'TheSilphRoad',
#  'Torchlight',
#  'Tribes',
#  'TrollXChromosomes',
#  'TrueAskReddit',
#  'TrueAtheism',
#  'TrueDetective',
#  'TrueReddit',
#  'TumblrInAction',
#  'Twitch',
#  'TwoXChromosomes',
#  'Ubuntu',
#  'UkrainianConflict',
#  'UniversityofReddit',
#  'UnresolvedMysteries',
#  'UpliftingNews',
#  'Vermintide',
#  'Vive',
#  'WTF',
#  'Warframe',
#  'Warthunder',
#  'Watches',
#  'WayOfTheBern',
#  'WeAreTheMusicMakers',
#  'WebGames',
#  'Whatcouldgowrong',
#  'WhereIsAssange',
#  'WikiLeaks',
#  'WildStar',
#  'Windows10',
#  'WorldOfWarships',
#  'WorldofTanks',
#  'WritingPrompts',
#  'Xcom',
#  'YouShouldKnow',
#  'actuallesbians',
#  'adventuretime',
#  'aiclass',
#  'americanpirateparty',
#  'amiugly',
#  'anime',
#  'announcements',
#  'answers',
#  'apple',
#  'archeage',
#  'askgaybros',
#  'askscience',
#  'asktransgender',
#  'asoiaf',
#  'assassinscreed',
#  'atheism',
#  'australia',
#  'aviation',
#  'aww',
#  'badcompany2',
#  'baseball',
#  'basement',
#  'batman',
#  'battlefield3',
#  'battlefield_4',
#  'battlestations',
#  'beer',
#  'bestof',
#  'bestof2010',
#  'bestoflegaladvice',
#  'bicycling',
#  'bjj',
#  'blackops2',
#  'blog',
#  'bloodborne',
#  'boardgames',
#  'bodybuilding',
#  'books',
#  'booksuggestions',
#  'boston',
#  'brasil',
#  'breakingbad',
#  'britishproblems',
#  'btc',
#  'buildapc',
#  'business',
#  'canada',
#  'cars',
#  'casualiama',
#  'cats',
#  'changemyview',
#  'chicago',
#  'childfree',
#  'churning',
#  'circlebroke',
#  'circlejerk',
#  'civ',
#  'civbeyondearth',
#  'codbo',
#  'cogsci',
#  'comicbooks',
#  'comics',
#  'community',
#  'confession',
#  'conspiracy',
#  'conspiratard',
#  'cosplay',
#  'creepy',
#  'creepyPMs',
#  'cringe',
#  'cscareerquestions',
#  'dankmemes',
#  'darksouls',
#  'dataisbeautiful',
#  'dating_advice',
#  'dayz',
#  'de',
#  'depression',
#  'diablo3',
#  'dndnext',
#  'doctorwho',
#  'dogs',
#  'dragonage',
#  'drunk',
#  'dubstep',
#  'ebola',
#  'edmproduction',
#  'elderscrollsonline',
#  'electronic_cigarette',
#  'electronicmusic',
#  'energy',
#  'engineering',
#  'entertainment',
#  'environment',
#  'esist',
#  'ethereum',
#  'europe',
#  'european',
#  'exmormon',
#  'explainlikeIAmA',
#  'explainlikeimfive',
#  'facepalm',
#  'factorio',
#  'fantasybaseball',
#  'fantasyfootball',
#  'fatlogic',
#  'fatpeoplestories',
#  'feedthebeast',
#  'femalefashionadvice',
#  'fffffffuuuuuuuuuuuu',
#  'ffxiv',
#  'financialindependence',
#  'firstworldproblems',
#  'food',
#  'formula1',
#  'france',
#  'freebies',
#  'frugalmalefashion',
#  'ftlgame',
#  'fullmoviesonyoutube',
#  'funny',
#  'gadgets',
#  'gallifrey',
#  'gamedev',
#  'gamegrumps',
#  'gameofthrones',
#  'gamernews',
#  'gameswap',
#  'gaming',
#  'gardening',
#  'gaybros',
#  'gaymers',
#  'geek',
#  'gentlemanboners',
#  'gifs',
#  'golf',
#  'gonewild',
#  'google',
#  'googleplus',
#  'googleplusinvites',
#  'guns',
#  'h1z1',
#  'halo',
#  'happy',
#  'hardware',
#  'harrypotter',
#  'headphones',
#  'hearthstone',
#  'heroesofthestorm',
#  'hiphopheads',
#  'history',
#  'hockey',
#  'hoi4',
#  'horror',
#  'humor',
#  'india',
#  'interstellar',
#  'investing',
#  'iphone',
#  'islam',
#  'itookapicture',
#  'jobs',
#  'keto',
#  'kpop',
#  'law',
#  'leagueoflegends',
#  'learnprogramming',
#  'legaladvice',
#  'lgbt',
#  'lifehacks',
#  'lifeisstrange',
#  'linux',
#  'listentothis',
#  'litecoin',
#  'london',
#  'loseit',
#  'lost',
#  'madmen',
#  'magicTCG',
#  'malefashionadvice',
#  'manga',
#  'masseffect',
#  'math',
#  'mcservers',
#  'mildlyinteresting',
#  'mindcrack',
#  'motorcycles',
#  'movies',
#  'mw3',
#  'mylittlepony',
#  'nba',
#  'needadvice',
#  'netsec',
#  'news',
#  'newsokur',
#  'newzealand',
#  'nfl',
#  'nintendo',
#  'nosleep',
#  'nottheonion',
#  'nsfw',
#  'nyc',
#  'obama',
#  'occupywallstreet',
#  'oculus',
#  'offbeat',
#  'offmychest',
#  'olympics',
#  'outside',
#  'paradoxplaza',
#  'paragon',
#  'pathofexile',
#  'patientgamers',
#  'paydaytheheist',
#  'pcgaming',
#  'personalfinance',
#  'pettyrevenge',
#  'philosophy',
#  'photography',
#  'photoshopbattles',
#  'pics',
#  'playark',
#  'playitforward',
#  'playrust',
#  'podemos',
#  'pokemon',
#  'politics',
#  'programming',
#  'projecteternity',
#  'promos',
#  'psychology',
#  'r4r',
#  'rage',
#  'raisedbynarcissists',
#  'reactiongifs',
#  'reddevils',
#  'reddit.com',
#  'relationship_advice',
#  'relationships',
#  'residentevil',
#  'restorethefourth',
#  'rocketbeans',
#  'ronpaul',
#  'rpg',
#  'runescape',
#  'running',
#  'sandy',
#  'science',
#  'scifi',
#  'secretsanta',
#  'seduction',
#  'self',
#  'serialpodcast',
#  'sex',
#  'shittyadvice',
#  'shittyaskscience',
#  'shutupandtakemymoney',
#  'skeptic',
#  'skyrim',
#  'skyrimmods',
#  'smashbros',
#  'snowboarding',
#  'soccer',
#  'socialism',
#  'space',
#  'spacex',
#  'spikes',
#  'sports',
#  'starcitizen',
#  'starcraft',
#  'startrek',
#  'summonerschool',
#  'sweden',
#  'swtor',
#  'syriancivilwar',
#  'sysadmin',
#  'talesfromtechsupport',
#  'tall',
#  'tattoos',
#  'tech',
#  'technology',
#  'techsupport',
#  'teenagers',
#  'television',
#  'teslamotors',
#  'tf2',
#  'tf2trade',
#  'thedivision',
#  'thelastofus',
#  'thenetherlands',
#  'thesims',
#  'thewalkingdead',
#  'theydidthemath',
#  'tifu',
#  'til',
#  'tipofmytongue',
#  'titanfall',
#  'todayilearned',
#  'toronto',
#  'totalwar',
#  'travel',
#  'treecomics',
#  'trees',
#  'truegaming',
#  'twinpeaks',
#  'ukpolitics',
#  'unitedkingdom',
#  'vancouver',
#  'vaporents',
#  'vegan',
#  'videos',
#  'vinyl',
#  'vita',
#  'watchpeopledie',
#  'wc2010_crests',
#  'web_design',
#  'webdev',
#  'weddingplanning',
#  'westworld',
#  'whatisthisthing',
#  'whowouldwin',
#  'wicked_edge',
#  'wiiu',
#  'wikipedia',
#  'windowsphone',
#  'woahdude',
#  'woodworking',
#  'worldbuilding',
#  'worldnews',
#  'worldpolitics',
#  'wow',
#  'writing',
#  'xbox360',
#  'xboxone',
#  'xxfitness',
#  'yugioh',
#  'zelda',
#  'zombies'}
